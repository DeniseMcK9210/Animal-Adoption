# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./Data/AAC_In_Out_Final.csv")
df.head()
#list(df.columns)
#print(df.dtypes)
#df.Breed2.unique()
# Out:
#   Animal ID    Name        Date of Birth Gender    Color1 Color2  \
# 0   A006100   Scamp  2007-07-09 00:00:00   Male    Yellow  White
# 1   A006100   Scamp  2007-07-09 00:00:00   Male    Yellow  White
# 2   A006100   Scamp  2007-07-09 00:00:00   Male    Yellow  White
# 3   A047759    Oreo  2004-04-02 00:00:00   Male  Tricolor   none
# 4   A134067  Bandit  1997-10-16 00:00:00   Male     Brown  White
#
#               Breed1 Breed2          Found Street Found City  ...  \
# 0  Spinone Italiano     Mix  2501 Magin Meadow Dr    Austin   ...
# 1  Spinone Italiano     Mix     9409 Bluegrass Dr    Austin   ...
# 2  Spinone Italiano     Mix   2818 Palomino Trail    Austin   ...
# 3          Dachshund   none        800 Grove Blvd    Austin   ...
# 4  Shetland Sheepdog   none                  none    Austin   ...
#
#        Intake Type Intake Condition Age upon Intake Intake_Sex  \
# 0    Public Assist           Normal         6 years   Neutered
# ...

# %%
# drop unecessary columns
dog_df1 = df[["Gender", "Date of Birth", "Color1", "Color2", "Breed1", "Breed2", "Intake_Date", "Intake Type", "Intake Condition", "Intake_Sex", "Outcome_Date", "Outcome Type", "Outcome_Age_Months", "Outcome_Sex", "AAC_Duration"]]
dog_df1.head()
# Out:
#   Gender        Date of Birth    Color1 Color2             Breed1 Breed2  \
# 0   Male  2007-07-09 00:00:00    Yellow  White  Spinone Italiano     Mix
# 1   Male  2007-07-09 00:00:00    Yellow  White  Spinone Italiano     Mix
# 2   Male  2007-07-09 00:00:00    Yellow  White  Spinone Italiano     Mix
# 3   Male  2004-04-02 00:00:00  Tricolor   none          Dachshund   none
# 4   Male  1997-10-16 00:00:00     Brown  White  Shetland Sheepdog   none
#
#            Intake_Date      Intake Type Intake Condition Intake_Sex  \
# 0  2014-03-07 14:26:00    Public Assist           Normal   Neutered
# 1  2017-12-07 14:07:00            Stray           Normal   Neutered
# 2  2014-12-19 10:21:00    Public Assist           Normal   Neutered
# 3  2014-04-02 15:55:00  Owner Surrender           Normal   Neutered
# 4  2013-11-16 09:02:00    Public Assist          Injured   Neutered
#
#           Outcome_Date     Outcome Type  Outcome_Age_Months Outcome_Sex  \
# ...

# %%
# Get min and max of Outcome_Age_Months column
dog_df1["Outcome_Age_Months"].max()
dog_df1["Outcome_Age_Months"].min()

# Drop AAC_Duration, and Outcome_Age_Months rows with negative values
dog_df2 = dog_df1[dog_df1["Outcome_Age_Months"] >=0]
# Out:
# -12

# %%
#dog_df1["AAC_Duration"].apply()

dog_df1["AAC_Duration_Clean"] = pd.to_timedelta(dog_df1["AAC_Duration"])
# Out:
# /Users/suprajasharma/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from datetime import datetime as dt

# %%
def td_cleaner2(timed):
    seconds = timed.total_seconds()
    return(seconds)

# %%
dog_df1["TDSeconds"] = dog_df1.AAC_Duration_Clean.apply(td_cleaner2)
# Out:
# /Users/suprajasharma/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dog_df1["TDSeconds"]

dog_df2 = dog_df1[dog_df1["TDSeconds"] >=0]

dog_df2
# Out:
#        Gender        Date of Birth         Color1    Color2  \
# 0        Male  2007-07-09 00:00:00         Yellow     White
# 2        Male  2007-07-09 00:00:00         Yellow     White
# 3        Male  2004-04-02 00:00:00       Tricolor      none
# 4        Male  1997-10-16 00:00:00          Brown     White
# 5      Female  1998-06-01 00:00:00          Black     White
# 6      Female  1999-10-19 00:00:00          Black      Gray
# 7        Male  1999-08-18 00:00:00          Brown     White
# 8        Male  1999-03-17 00:00:00          White     Black
# 9      Female  1997-08-01 00:00:00          Brown     White
# 10       Male  1997-10-03 00:00:00          Black       Tan
# 11       Male  2000-04-27 00:00:00          Black     White
# 12       Male  1999-06-01 00:00:00            Tan     Black
# 13     Female  2000-03-05 00:00:00            Tan     Black
# 14       Male  2001-01-17 00:00:00          Black      none
# 15       Male  1998-10-19 00:00:00           Gold      Gold
# ...
